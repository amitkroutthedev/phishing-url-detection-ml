# %% [markdown]
# <a href="https://colab.research.google.com/github/BladeArya/phising-url-detection-ml/blob/main/legitmate_url_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Phishing Website Detection Feature Extraction(Part - 2)**

# %% [markdown]
# # **Legitimate URLs**

# %% [markdown]
# ## **Data Collection**
# For the legitimate URLs, I found a source that has a collection of benign, spam, phishing, malware & defacement URLs. The source of the dataset is University of New Brunswick, https://www.unb.ca/cic/datasets/url-2016.html. The number of legitimate URLs in this collection are 35,300. The URL collection is downloaded & from that, *'Benign_list_big_final.csv'* is the file of our interest. This file is then uploaded to the Colab for the feature extraction.

# %%
import pandas as pd

# %%
raw_data = pd.read_csv("https://raw.githubusercontent.com/BladeArya/phising-url-detection-ml/main/dataset/Benign_list_big_final.csv")

# %%
raw_data.head()
raw_data.columns = ['URLs']
raw_data.head()
# Out:
#                                                 URLs
# 0  http://1337x.to/torrent/1110018/Blackhat-2015-...
# 1  http://1337x.to/torrent/1122940/Blackhat-2015-...
# 2  http://1337x.to/torrent/1124395/Fast-and-Furio...
# 3  http://1337x.to/torrent/1145504/Avengers-Age-o...
# 4  http://1337x.to/torrent/1160078/Avengers-age-o...

# %%
legitdataset = raw_data.sample(n = 1000, random_state = 12).copy()
legitdataset = legitdataset.reset_index(drop=True)
legitdataset.head()
# Out:
#                                                 URLs
# 0  http://graphicriver.net/search?date=this-month...
# 1  http://ecnavi.jp/redirect/?url=http://www.cros...
# 2  https://hubpages.com/signin?explain=follow+Hub...
# 3  http://extratorrent.cc/torrent/4190536/AOMEI+B...
# 4  http://icicibank.com/Personal-Banking/offers/o...

# %%
legitdataset.shape
# Out:
# (1000, 1)

# %%
seperation_of_protocol = legitdataset['URLs'].str.split("://",expand = True)

# %%
seperation_of_protocol.head()
# Out:
#        0  ...                                                  2
# 0   http  ...                                               None
# 1   http  ...  www.cross-a.net/x.php?id=1845_3212_22061_26563...
# 2  https  ...                                               None
# 3   http  ...                                               None
# 4   http  ...                                               None
#
# [5 rows x 3 columns]

# %%
seperation_domain_name = seperation_of_protocol[1].str.split("/",1,expand = True)

# %%
seperation_domain_name.columns=["domain_name","address"]

# %%
seperation_domain_name.head()
# Out:
#         domain_name                                            address
# 0  graphicriver.net  search?date=this-month&length_max=&length_min=...
# 1         ecnavi.jp                                 redirect/?url=http
# 2      hubpages.com  signin?explain=follow+Hubs&url=%2Fhub%2FComfor...
# 3   extratorrent.cc  torrent/4190536/AOMEI+Backupper+Technician+%2B...
# 4     icicibank.com  Personal-Banking/offers/offer-detail.page?id=o...

# %%
legiturldata = pd.concat([seperation_of_protocol[0],seperation_domain_name],axis=1)

# %%
legiturldata.columns = ['protocol','domain_name','address']

# %%
legiturldata.head()
# Out:
#   protocol       domain_name                                            address
# 0     http  graphicriver.net  search?date=this-month&length_max=&length_min=...
# 1     http         ecnavi.jp                                 redirect/?url=http
# 2    https      hubpages.com  signin?explain=follow+Hubs&url=%2Fhub%2FComfor...
# 3     http   extratorrent.cc  torrent/4190536/AOMEI+Backupper+Technician+%2B...
# 4     http     icicibank.com  Personal-Banking/offers/offer-detail.page?id=o...

# %%
legiturldata.shape
# Out:
# (1000, 3)

# %% [markdown]
# # **Feature Extraction**
# In this step, features are extracted from the URLs dataset.
#
# The extracted features are categorized into
#
#
# 1.   Address Bar based Features
# 2.   Domain/Abnormal based Features
# 3.   HTML & Javascript based Features

# %% [markdown]
# ### **1. Address Bar based Features**
#
#
# *   IP Address in URL
# *   Length of URL
# *   Using URL Shortening Services “TinyURL”
# *   "@" Symbol in URL
# *   Redirection "//" in URL
# *   Prefix or Suffix "-" in Domain
# *   Depth of URL(Domain and Sub-Domain)
# *   "http/https" in Domain name

# %%
import ipaddress
import re

# %%
#1. Using the IP Address
def having_ip_address(url):
  try:
    ipaddress.ip_address(url)
    ip = 1
  except:
    ip = 0
  return ip

# %%
legiturldata['having_ip_address'] = legitdataset['URLs'].apply(having_ip_address)

# %%
#2. Long URL
def long_url(l):
    if len(l) < 54:
        return 0
    elif len(l) >= 54 and len(l) <= 75:
        return 2
    return 1

# %%
legiturldata['long_url'] = legitdataset['URLs'].apply(long_url)

# %%
#3. Using URL Shortening Services “TinyURL”
def shortening_service(url):
    match=re.search('bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|'
                    'yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|'
                    'short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|'
                    'doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|'
                    'db\.tt|qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|'
                    'q\.gs|is\.gd|po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|'
                    'x\.co|prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|tr\.im|link\.zip\.net',url)
    if match:
        return 1
    else:
        return 0

# %%
legiturldata['shortening_service'] = legitdataset['URLs'].apply(shortening_service)

# %%
#4. URL’s having “@” Symbol
def have_at_symbol(l):
    if "@" in l:
        return 1
    return 0

# %%
legiturldata['having_@_symbol'] = legitdataset['URLs'].apply(have_at_symbol)

# %%
#5. Redirecting using “//”
def redirection(l):
    if "//" in l:
        return 1
    return 0

# %%
legiturldata['redirection_//_symbol'] = seperation_of_protocol[1].apply(redirection)

# %%
#6. Adding Prefix or Suffix Separated by (-) to the Domain
def prefix_suffix_seperation(l):
    if '-' in l:
        return 1
    return 0

# %%
legiturldata['prefix_suffix_seperation'] = seperation_domain_name['domain_name'].apply(prefix_suffix_seperation)

# %%
#7. Sub Domain and Multi Sub Domains
def sub_domains(l):
    if l.count('.') < 3:
        return 0
    elif l.count('.') == 3:
        return 2
    return 1

# %%
legiturldata['sub_domains'] = legiturldata['domain_name'].apply(sub_domains)

# %%
#8. The Existence of “HTTPS” Token in the Domain Part of the URL
def https_token(url):
    match=re.search('https://|http://',url)
    if match.start(0)==0:
        url=url[match.end(0):]
    match=re.search('http|https',url)
    if match:
        return 1
    else:
        return 0

# %%
legiturldata['https_token'] = legitdataset['URLs'].apply(https_token)

# %% [markdown]
# ### **2. Domain based Features**
#
#
# *   Age of Domain
# *   DNS Record
# *   Website Traffic
# *   Domain Registration Length
# *   Statistical-Reports Based Feature

# %%
# !pip install python-whois
# Out:
# Collecting python-whois
#   Downloading python-whois-0.7.3.tar.gz (91 kB)
#      |████████████████████████████████| 91 kB 5.6 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from python-whois) (0.16.0)
# Building wheels for collected packages: python-whois
#   Building wheel for python-whois (setup.py) ... done
#   Created wheel for python-whois: filename=python_whois-0.7.3-py3-none-any.whl size=87720 sha256=55c9c9c8649a80ded34fe73633b4d5901d354c04cd53488fc388273ff88785ab
#   Stored in directory: /root/.cache/pip/wheels/11/05/f7/895ce5a73665f77c8274a7d55e34fb3e6b4abbb9a7637e215b
# Successfully built python-whois
# Installing collected packages: python-whois
# Successfully installed python-whois-0.7.3

# %%
import whois
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
from datetime import datetime
import time
import socket
import re

# %%
#9. Age of Domain
def age_of_domain_sub(domain_name):
  creation_date = domain_name.creation_date
  expiration_date = domain_name.expiration_date
  if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
    try:
      creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
      expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
    except:
      return 1
  if ((expiration_date is None) or (creation_date is None)):
      return 1
  elif ((type(expiration_date) is list) or (type(creation_date) is list)):
      return 2
  else:
    ageofdomain = abs((expiration_date - creation_date).days)
    if ((ageofdomain/30) < 6):
      age = 1
    else:
      age = 0
  return age

# %%
def age_of_domain_main(domain):
    dns = 0
    try:
        domain_name = whois.whois(domain)
    except:
        dns = 1
        
    if dns == 1:
        return 1
    else:
        return age_of_domain_sub(domain_name)

# %%
legiturldata['age_of_domain'] = legitdataset['URLs'].apply(age_of_domain_main)
# Out:
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket

# %%
#10.DNS Record
def dns_record(domain):
    dns = 0
    try:
        domain_name = whois.whois(domain)
        print(domain_name)
    except:
        dns = 1
        
    if dns == 1:
        return 1
    else:
        return dns

# %%
legiturldata['dns_record'] = legiturldata['domain_name'].apply(dns_record)
# Out:
# Streaming output truncated to the last 5000 lines.
#   "country": "AU"
# }
# Error trying to connect to socket: closing socket
# {
#   "domain_name": null,
#   "registrar": null,
#   "whois_server": null,
#   "referral_url": null,
#   "updated_date": null,
#   "creation_date": null,
#   "expiration_date": null,
#   "name_servers": null,
#   "status": null,
#   "emails": null,
#   "dnssec": null,
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "XHAMSTER.COM",
#     "xhamster.com"
#   ],
#   "registrar": "NAMECHEAP INC",
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-03-03 07:50:16",
#     "2021-03-03 07:50:16.380000"
#   ],
#   "creation_date": "2007-04-02 12:48:32",
#   "expiration_date": "2022-04-02 12:48:32",
#   "name_servers": [
#     "ANUJ.NS.CLOUDFLARE.COM",
#     "SIMA.NS.CLOUDFLARE.COM",
#     "sima.ns.cloudflare.com",
#     "anuj.ns.cloudflare.com"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@namecheap.com",
#   "dnssec": "unsigned",
#   "name": "Redacted for Privacy Purposes",
#   "org": "Redacted for Privacy Purposes",
#   "address": "Redacted for Privacy Purposes",
#   "city": "Redacted for Privacy Purposes",
#   "state": "Limassol",
#   "zipcode": "Redacted for Privacy Purposes",
#   "country": "CY"
# }
# {
#   "domain_name": "COOKPAD.COM",
#   "registrar": "Network Solutions, LLC",
#   "whois_server": "whois.networksolutions.com",
#   "referral_url": null,
#   "updated_date": "2018-04-12 14:14:21",
#   "creation_date": "1999-04-12 04:00:00",
#   "expiration_date": "2028-04-12 04:00:00",
#   "name_servers": [
#     "NS-134.AWSDNS-16.COM",
#     "NS-1526.AWSDNS-62.ORG",
#     "NS-1805.AWSDNS-33.CO.UK",
#     "NS-582.AWSDNS-08.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@web.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "SERVERFAULT.COM",
#   "registrar": "Name.com, Inc.",
#   "whois_server": "whois.name.com",
#   "referral_url": null,
#   "updated_date": "2021-05-19 15:16:33",
#   "creation_date": "2009-03-15 03:13:53",
#   "expiration_date": "2023-03-15 03:13:53",
#   "name_servers": [
#     "NS-1135.AWSDNS-13.ORG",
#     "NS-860.AWSDNS-43.NET",
#     "NS-CLOUD-C1.GOOGLEDOMAINS.COM",
#     "NS-CLOUD-C2.GOOGLEDOMAINS.COM",
#     "ns-860.awsdns-43.net",
#     "ns-1135.awsdns-13.org",
#     "ns-cloud-c1.googledomains.com",
#     "ns-cloud-c2.googledomains.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited https://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": "abuse@name.com",
#   "dnssec": [
#     "unsigned",
#     "unSigned"
#   ],
#   "name": "Sysadmin Team",
#   "org": "Stack Exchange, Inc.",
#   "address": "110 William St , Floor 28",
#   "city": "New York",
#   "state": "NY",
#   "zipcode": "10038",
#   "country": "US"
# }
# {
#   "domain_name": null,
#   "registrar": null,
#   "registrar_url": null,
#   "status": null,
#   "registrant_name": null,
#   "registrant_type": null,
#   "registrant_street": null,
#   "registrant_city": null,
#   "registrant_country": null,
#   "creation_date": null,
#   "expiration_date": null,
#   "updated_date": null,
#   "name_servers": null
# }
# {
#   "domain_name": "web.de",
#   "status": "connect",
#   "updated_date": null,
#   "name": null,
#   "org": null,
#   "address": null,
#   "zipcode": null,
#   "city": null,
#   "country_code": null,
#   "phone": null,
#   "fax": null,
#   "name_servers": null,
#   "emails": null
# }
# {
#   "domain_name": "DISTRACTIFY.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-01-30 18:43:01",
#     "2021-01-30 13:42:58"
#   ],
#   "creation_date": [
#     "2013-01-29 09:58:25",
#     "2013-01-29 04:58:25"
#   ],
#   "expiration_date": [
#     "2022-01-29 09:58:25",
#     "2022-01-29 04:58:25"
#   ],
#   "name_servers": [
#     "NS1.DNSIMPLE.COM",
#     "NS2.DNSIMPLE.COM",
#     "NS3.DNSIMPLE.COM",
#     "NS4.DNSIMPLE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Distractify.com LLC",
#   "address": null,
#   "city": null,
#   "state": "New York",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "ELITEDAILY.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-07-14 10:39:04",
#   "creation_date": "2011-08-30 17:16:40",
#   "expiration_date": "2030-08-30 17:16:40",
#   "name_servers": [
#     "NS-1524.AWSDNS-62.ORG",
#     "NS-1717.AWSDNS-22.CO.UK",
#     "NS-480.AWSDNS-60.COM",
#     "NS-808.AWSDNS-37.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "PIKABU.RU",
#   "registrar": "REGRU-RU",
#   "creation_date": "2009-04-03 20:00:00",
#   "expiration_date": "2022-04-03 21:00:00",
#   "name_servers": [
#     "alla.ns.cloudflare.com.",
#     "phil.ns.cloudflare.com."
#   ],
#   "status": "REGISTERED, DELEGATED, VERIFIED",
#   "emails": null,
#   "org": null
# }
# {
#   "domain_name": [
#     "THENEXTWEB.COM",
#     "thenextweb.com"
#   ],
#   "registrar": "NAMECHEAP INC",
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-07-03 07:38:47",
#     "2021-07-03 07:38:47.410000"
#   ],
#   "creation_date": "2008-08-02 19:06:27",
#   "expiration_date": "2022-08-02 19:06:27",
#   "name_servers": [
#     "ANUJ.NS.CLOUDFLARE.COM",
#     "ROSA.NS.CLOUDFLARE.COM",
#     "anuj.ns.cloudflare.com",
#     "rosa.ns.cloudflare.com"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@namecheap.com",
#     "b4743c8cb7b94c60ab163a66bd49a1fb.protect@withheldforprivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Redacted for Privacy",
#   "org": "Privacy service provided by Withheld for Privacy ehf",
#   "address": "Kalkofnsvegur 2",
#   "city": "Reykjavik",
#   "state": "Capital Region",
#   "zipcode": "101",
#   "country": "IS"
# }
# {
#   "domain_name": "metro.co.uk",
#   "registrar": "Nom-IQ Limited t/a Com Laude [Tag = NOMIQ]",
#   "registrar_url": "https://comlaude.com",
#   "status": "Registered until expiry date.",
#   "registrant_name": null,
#   "registrant_type": null,
#   "registrant_street": null,
#   "registrant_city": null,
#   "registrant_country": null,
#   "creation_date": "before Aug-1996",
#   "expiration_date": "2028-06-17 00:00:00",
#   "updated_date": "2019-02-15 00:00:00",
#   "name_servers": "a1-204.akam.net"
# }
# {
#   "domain_name": "PLARIUM.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-04-05 15:51:40",
#     "2021-04-05 10:51:37"
#   ],
#   "creation_date": [
#     "2010-04-04 20:54:03",
#     "2010-04-04 15:54:03"
#   ],
#   "expiration_date": [
#     "2022-04-04 20:54:03",
#     "2022-04-04 15:54:03"
#   ],
#   "name_servers": [
#     "MAREK.NS.CLOUDFLARE.COM",
#     "MARJORY.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Plarium Global Ltd",
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": "IL"
# }
# {
#   "domain_name": [
#     "TWITTER.COM",
#     "twitter.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2022-01-17 06:08:20",
#     "2022-01-17 01:08:20"
#   ],
#   "creation_date": [
#     "2000-01-21 16:28:17",
#     "2000-01-21 11:28:17"
#   ],
#   "expiration_date": "2023-01-21 16:28:17",
#   "name_servers": [
#     "A.R06.TWTRDNS.NET",
#     "B.R06.TWTRDNS.NET",
#     "C.R06.TWTRDNS.NET",
#     "D.R06.TWTRDNS.NET",
#     "D01-01.NS.TWTRDNS.NET",
#     "D01-02.NS.TWTRDNS.NET",
#     "NS3.P34.DYNECT.NET",
#     "NS4.P34.DYNECT.NET",
#     "c.r06.twtrdns.net",
#     "d01-01.ns.twtrdns.net",
#     "d.r06.twtrdns.net",
#     "d01-02.ns.twtrdns.net",
#     "b.r06.twtrdns.net",
#     "a.r06.twtrdns.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited https://icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited",
#     "serverDeleteProhibited http://www.icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited http://www.icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited http://www.icann.org/epp#serverUpdateProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "domains@twitter.com",
#     "domains-tech@twitter.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Twitter, Inc.",
#   "org": "Twitter, Inc.",
#   "address": "1355 Market Street",
#   "city": "San Francisco",
#   "state": "CA",
#   "zipcode": "94103",
#   "country": "US"
# }
# {
#   "domain_name": "SEEKINGALPHA.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-07-31 23:24:45",
#   "creation_date": "2004-09-03 20:40:52",
#   "expiration_date": "2022-09-03 20:40:52",
#   "name_servers": [
#     "NS-1331.AWSDNS-38.ORG",
#     "NS-1782.AWSDNS-30.CO.UK",
#     "NS-243.AWSDNS-30.COM",
#     "NS-795.AWSDNS-35.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "THENEXTWEB.COM",
#     "thenextweb.com"
#   ],
#   "registrar": "NAMECHEAP INC",
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-07-03 07:38:47",
#     "2021-07-03 07:38:47.410000"
#   ],
#   "creation_date": "2008-08-02 19:06:27",
#   "expiration_date": "2022-08-02 19:06:27",
#   "name_servers": [
#     "ANUJ.NS.CLOUDFLARE.COM",
#     "ROSA.NS.CLOUDFLARE.COM",
#     "anuj.ns.cloudflare.com",
#     "rosa.ns.cloudflare.com"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@namecheap.com",
#     "b4743c8cb7b94c60ab163a66bd49a1fb.protect@withheldforprivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Redacted for Privacy",
#   "org": "Privacy service provided by Withheld for Privacy ehf",
#   "address": "Kalkofnsvegur 2",
#   "city": "Reykjavik",
#   "state": "Capital Region",
#   "zipcode": "101",
#   "country": "IS"
# }
# {
#   "domain_name": [
#     "XVIDEO-JP.COM",
#     "xvideo-jp.com"
#   ],
#   "registrar": "GMO INTERNET, INC.",
#   "whois_server": "whois.discount-domain.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-04-10 23:11:00",
#     "2021-04-11 08:11:00"
#   ],
#   "creation_date": "2012-05-10 00:27:37",
#   "expiration_date": "2022-05-10 00:27:37",
#   "name_servers": [
#     "DNS01.MUUMUU-DOMAIN.COM",
#     "DNS02.MUUMUU-DOMAIN.COM",
#     "dns01.muumuu-domain.com",
#     "dns02.muumuu-domain.com"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@gmo.jp",
#     "privacy@whoisprivacyprotection.info"
#   ],
#   "dnssec": "unsigned",
#   "name": "Whois Privacy Protection Service by MuuMuuDomain",
#   "org": "Whois Privacy Protection Service by MuuMuuDomain",
#   "address": [
#     "2-7-21 Tenjin Chuo-ku",
#     "Tenjin Prime 8F"
#   ],
#   "city": "Fukuoka-shi",
#   "state": "Fukuoka",
#   "zipcode": "810-0001",
#   "country": "JP"
# }
# {
#   "domain_name": "CHEEZBURGER.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": "2017-03-30 15:49:45",
#   "creation_date": "2005-12-31 04:47:04",
#   "expiration_date": "2026-12-31 04:47:04",
#   "name_servers": [
#     "NS0.DNSMADEEASY.COM",
#     "NS1.DNSMADEEASY.COM",
#     "NS2.DNSMADEEASY.COM",
#     "NS3.DNSMADEEASY.COM",
#     "NS4.DNSMADEEASY.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "AP.ORG",
#   "registrar": "Network Solutions, LLC",
#   "whois_server": "whois.networksolutions.com",
#   "referral_url": null,
#   "updated_date": "2018-07-24 16:22:12",
#   "creation_date": "1991-07-25 04:00:00",
#   "expiration_date": "2028-07-24 04:00:00",
#   "name_servers": [
#     "A11-64.AKAM.NET",
#     "A9-67.AKAM.NET",
#     "A10-67.AKAM.NET",
#     "A28-66.AKAM.NET",
#     "A24-65.AKAM.NET",
#     "A1-212.AKAM.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "domain.operations@web.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "The Associated Press",
#   "address": null,
#   "city": null,
#   "state": "NY",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "TORCACHE.NET",
#   "registrar": "Sea Wasp, LLC",
#   "whois_server": "whois.fabulous.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-04-13 06:08:49",
#     "2021-04-13 01:08:49"
#   ],
#   "creation_date": [
#     "2011-04-29 11:29:16",
#     "2011-04-29 06:29:16"
#   ],
#   "expiration_date": [
#     "2022-04-29 11:29:16",
#     "2022-04-29 06:29:16"
#   ],
#   "name_servers": [
#     "NS1.BODIS.COM",
#     "NS2.BODIS.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "renewPeriod (https://www.icann.org/epp#renewPeriod)"
#   ],
#   "emails": [
#     "abuse@fabulous.com",
#     "torcache.net@fab.JewellaPrivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Jewella Privacy - 1aa47",
#   "org": "Jewella Privacy LLC Privacy ID# 1183090",
#   "address": "5860 Citrus Blvd, Suite D, #172",
#   "city": "Harahan",
#   "state": "LA",
#   "zipcode": "70123",
#   "country": "US"
# }
# {
#   "domain_name": [
#     "KAKAKU.COM",
#     "kakaku.com"
#   ],
#   "registrar": "GMO INTERNET, INC.",
#   "whois_server": "whois.discount-domain.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-06-21 15:16:06",
#     "2021-06-22 00:16:06"
#   ],
#   "creation_date": "1998-07-08 04:00:00",
#   "expiration_date": "2022-07-07 04:00:00",
#   "name_servers": [
#     "NS-1440.AWSDNS-52.ORG",
#     "NS-1784.AWSDNS-31.CO.UK",
#     "NS-333.AWSDNS-41.COM",
#     "NS-566.AWSDNS-06.NET",
#     "ns-566.awsdns-06.net",
#     "ns-333.awsdns-41.com",
#     "ns-1440.awsdns-52.org",
#     "ns-1784.awsdns-31.co.uk"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@gmo.jp",
#     "domainadmins@kakaku.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "domain admins",
#   "org": "Kakaku.com, Inc.",
#   "address": "3-5-7 Ebisu-minami",
#   "city": "Shibuya-ku",
#   "state": "Tokyo",
#   "zipcode": "150-0022",
#   "country": "JP"
# }
# {
#   "domain_name": "CSS-TRICKS.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": "2020-01-29 14:54:10",
#   "creation_date": "2007-07-04 06:26:57",
#   "expiration_date": "2025-07-04 06:26:57",
#   "name_servers": [
#     "DAVE.NS.CLOUDFLARE.COM",
#     "FAY.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "BUZZFIL.NET",
#     "buzzfil.net"
#   ],
#   "registrar": "OVH, SAS",
#   "whois_server": "whois.ovh.com",
#   "referral_url": null,
#   "updated_date": [
#     "2022-01-01 13:43:16",
#     "2022-01-01 12:43:16"
#   ],
#   "creation_date": [
#     "2015-02-09 18:46:12",
#     "2015-02-09 17:46:12"
#   ],
#   "expiration_date": [
#     "2023-02-09 18:46:12",
#     "2023-02-09 17:46:12"
#   ],
#   "name_servers": [
#     "ERIN.NS.CLOUDFLARE.COM",
#     "HUGH.NS.CLOUDFLARE.COM",
#     "erin.ns.cloudflare.com",
#     "hugh.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "abuse@ovh.net",
#     "485fq2wdeazxyjbk1q5z@e.o-w-o.info",
#     "73rpdm8d84xkmzzoxpai@n.o-w-o.info"
#   ],
#   "dnssec": "unsigned",
#   "name": "REDACTED FOR PRIVACY",
#   "org": null,
#   "address": "REDACTED FOR PRIVACY",
#   "city": "REDACTED FOR PRIVACY",
#   "state": null,
#   "zipcode": "REDACTED FOR PRIVACY",
#   "country": "SN"
# }
# {
#   "domain_name": "NESN.COM",
#   "registrar": "Network Solutions, LLC",
#   "whois_server": "whois.networksolutions.com",
#   "referral_url": null,
#   "updated_date": "2021-05-16 07:49:48",
#   "creation_date": "1995-07-16 04:00:00",
#   "expiration_date": "2024-07-15 04:00:00",
#   "name_servers": [
#     "NS1.WORDPRESS.COM",
#     "NS2.WORDPRESS.COM",
#     "NS3.WORDPRESS.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@web.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "TECHCRUNCH.COM",
#     "techcrunch.com"
#   ],
#   "registrar": "MarkMonitor, Inc.",
#   "whois_server": "whois.markmonitor.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-05-10 09:08:31",
#     "2021-12-17 00:12:45"
#   ],
#   "creation_date": "2005-06-10 22:56:20",
#   "expiration_date": [
#     "2022-06-10 22:56:20",
#     "2022-06-10 07:00:00"
#   ],
#   "name_servers": [
#     "NS1.TECHCRUNCH.COM",
#     "NS2.TECHCRUNCH.COM",
#     "NS3.TECHCRUNCH.COM",
#     "NS4.TECHCRUNCH.COM",
#     "ns3.techcrunch.com",
#     "ns1.techcrunch.com",
#     "ns2.techcrunch.com",
#     "ns4.techcrunch.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited https://icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "serverUpdateProhibited (https://www.icann.org/epp#serverUpdateProhibited)",
#     "serverTransferProhibited (https://www.icann.org/epp#serverTransferProhibited)",
#     "serverDeleteProhibited (https://www.icann.org/epp#serverDeleteProhibited)"
#   ],
#   "emails": [
#     "abusecomplaints@markmonitor.com",
#     "whoisrequest@markmonitor.com"
#   ],
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Yahoo Assets LLC",
#   "address": null,
#   "city": null,
#   "state": "VA",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": [
#     "IO9.COM",
#     "io9.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-11-28 06:11:42",
#     "2021-11-28 01:11:42"
#   ],
#   "creation_date": [
#     "1999-12-02 15:08:09",
#     "1999-12-02 10:08:09"
#   ],
#   "expiration_date": "2022-12-02 15:08:09",
#   "name_servers": [
#     "NS-110.AWSDNS-13.COM",
#     "NS-1146.AWSDNS-15.ORG",
#     "NS-1835.AWSDNS-37.CO.UK",
#     "NS-624.AWSDNS-14.NET",
#     "ns-1146.awsdns-15.org",
#     "ns-624.awsdns-14.net",
#     "ns-1835.awsdns-37.co.uk",
#     "ns-110.awsdns-13.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "dnsadmin@gizmodomedia.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "DNS Admin",
#   "org": "G/O Media Inc",
#   "address": "1540 Broadway 27th Floor",
#   "city": "New York",
#   "state": "NY",
#   "zipcode": "10036",
#   "country": "US"
# }
# {
#   "domain_name": [
#     "JALOPNIK.COM",
#     "jalopnik.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-08-09 20:57:36",
#     "2021-08-09 16:57:36"
#   ],
#   "creation_date": [
#     "2004-09-08 22:37:56",
#     "2004-09-08 18:37:56"
#   ],
#   "expiration_date": "2022-09-08 22:37:56",
#   "name_servers": [
#     "NS-110.AWSDNS-13.COM",
#     "NS-1146.AWSDNS-15.ORG",
#     "NS-1835.AWSDNS-37.CO.UK",
#     "NS-624.AWSDNS-14.NET",
#     "ns-1146.awsdns-15.org",
#     "ns-110.awsdns-13.com",
#     "ns-1835.awsdns-37.co.uk",
#     "ns-624.awsdns-14.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "dnsadmin@gizmodomedia.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "DNS Admin",
#   "org": "G/O Media Inc",
#   "address": "1540 Broadway 27th Floor",
#   "city": "New York",
#   "state": "NY",
#   "zipcode": "10036",
#   "country": "US"
# }
# {
#   "domain_name": "UDN.COM",
#   "registrar": "Network Solutions, LLC",
#   "whois_server": "whois.networksolutions.com",
#   "referral_url": null,
#   "updated_date": "2021-03-30 08:54:40",
#   "creation_date": "1998-09-10 04:00:00",
#   "expiration_date": "2026-09-09 04:00:00",
#   "name_servers": [
#     "A1-8.AKAM.NET",
#     "A13-65.AKAM.NET",
#     "A2-66.AKAM.NET",
#     "A26-67.AKAM.NET",
#     "A7-64.AKAM.NET",
#     "A8-65.AKAM.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@web.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# Error trying to connect to socket: closing socket
# {
#   "domain_name": null,
#   "registrar": null,
#   "whois_server": null,
#   "referral_url": null,
#   "updated_date": null,
#   "creation_date": null,
#   "expiration_date": null,
#   "name_servers": null,
#   "status": null,
#   "emails": null,
#   "dnssec": null,
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "ELITEDAILY.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-07-14 10:39:04",
#   "creation_date": "2011-08-30 17:16:40",
#   "expiration_date": "2030-08-30 17:16:40",
#   "name_servers": [
#     "NS-1524.AWSDNS-62.ORG",
#     "NS-1717.AWSDNS-22.CO.UK",
#     "NS-480.AWSDNS-60.COM",
#     "NS-808.AWSDNS-37.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "MEDIUM.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-04-21 23:16:31",
#   "creation_date": "1998-05-27 04:00:00",
#   "expiration_date": "2022-05-26 04:00:00",
#   "name_servers": [
#     "ALINA.NS.CLOUDFLARE.COM",
#     "KIP.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "EMGN.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-06-21 18:07:52",
#     "2021-06-21 13:07:50"
#   ],
#   "creation_date": [
#     "2004-06-20 18:57:38",
#     "2004-06-20 13:57:38"
#   ],
#   "expiration_date": [
#     "2022-06-20 18:57:38",
#     "2022-06-20 13:57:38"
#   ],
#   "name_servers": [
#     "NS-1508.AWSDNS-60.ORG",
#     "NS-1606.AWSDNS-08.CO.UK",
#     "NS-185.AWSDNS-23.COM",
#     "NS-894.AWSDNS-47.NET"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Domains By Proxy, LLC",
#   "address": null,
#   "city": null,
#   "state": "Arizona",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "AKHBARELYOM.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": "2020-01-23 20:04:11",
#   "creation_date": "2001-12-31 14:08:18",
#   "expiration_date": "2024-12-31 14:08:18",
#   "name_servers": [
#     "HAL.NS.CLOUDFLARE.COM",
#     "NIA.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "allegro.pl",
#   "name_servers": "dns1.allegro.pl. [2a02:dcc:20::5][91.194.188.132]\r\r\n                       dns2.allegro.pl. [91.207.14.244][2a02:dc8:20::5]\r\r\n                       dns3.allegro.pl. [46.229.156.195][2001:1a68:25:0:0:0:0:3]\r\r\n                       dns4.allegro.pl. [2001:2000:3080:17:0:0:0:3][62.115.165.115]",
#   "registrar": "Corporation Service Company",
#   "registrar_url": null,
#   "status": null,
#   "registrant_name": null,
#   "creation_date": "1999-10-27 13:00:00",
#   "expiration_date": "2022-10-26 15:00:00",
#   "updated_date": "2021-10-18 07:08:50"
# }
# {
#   "domain_name": [
#     "TORRENTDN.COM",
#     "torrentdn.com"
#   ],
#   "registrar": "Wild West Domains, LLC",
#   "whois_server": "whois.wildwestdomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-03-23 13:35:18",
#     "2021-03-23 08:35:15"
#   ],
#   "creation_date": [
#     "2015-03-24 07:05:16",
#     "2015-03-24 02:05:16"
#   ],
#   "expiration_date": [
#     "2022-03-24 07:05:16",
#     "2022-03-24 02:05:16"
#   ],
#   "name_servers": [
#     "NS1.PARKLOGIC.COM",
#     "NS2.PARKLOGIC.COM",
#     "NS3.PARKLOGIC.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@wildwestdomains.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Domains By Proxy, LLC",
#   "address": null,
#   "city": null,
#   "state": "Arizona",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "EVERNOTE.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": "2020-02-27 19:29:51",
#   "creation_date": "2000-01-20 04:38:40",
#   "expiration_date": "2029-01-20 04:38:40",
#   "name_servers": [
#     "BOB.NS.CLOUDFLARE.COM",
#     "NS10.DNSMADEEASY.COM",
#     "PIPER.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "WIKIMAPIA.ORG",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": "2021-01-27 08:00:23",
#   "creation_date": "2006-01-26 21:09:47",
#   "expiration_date": "2024-01-26 21:09:47",
#   "name_servers": [
#     "NS1.FIRST-NS.DE",
#     "ROBOTNS2.SECOND-NS.DE",
#     "ROBOTNS3.SECOND-NS.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": "Not Applicable",
#   "zipcode": null,
#   "country": "RU"
# }
# {
#   "domain_name": "TEBYAN.NET",
#   "registrar": "DNC Holdings, Inc",
#   "whois_server": "whois.directnic.com",
#   "referral_url": null,
#   "updated_date": [
#     "2019-11-09 12:28:27",
#     "2019-11-09 06:28:27"
#   ],
#   "creation_date": [
#     "2001-12-22 08:28:47",
#     "2001-12-22 02:28:47"
#   ],
#   "expiration_date": [
#     "2027-12-22 08:28:47",
#     "2027-12-22 02:28:47"
#   ],
#   "name_servers": [
#     "NS1.TEBYANIDCNS.IR",
#     "NS2.TEBYANIDCNS.IR"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)"
#   ],
#   "emails": [
#     "abuse@directnic.com",
#     "tebyan.net@dnic.JewellaPrivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Jewella Privacy - fd039",
#   "org": "Jewella Privacy LLC Privacy ID# 1009997",
#   "address": "5860 Citrus Blvd, Suite D, #172",
#   "city": "Harahan",
#   "state": "LA",
#   "zipcode": "70123",
#   "country": "US"
# }
# {
#   "domain_name": [
#     "MOVIEPILOT.COM",
#     "moviepilot.com"
#   ],
#   "registrar": "ENOM, INC.",
#   "whois_server": "WHOIS.ENOM.COM",
#   "referral_url": null,
#   "updated_date": "2021-03-15 14:23:03",
#   "creation_date": [
#     "2003-04-09 15:02:30",
#     "2003-04-09 15:02:00"
#   ],
#   "expiration_date": [
#     "2022-04-09 15:02:30",
#     "2022-04-09 15:02:00"
#   ],
#   "name_servers": [
#     "DNS1.NAME-SERVICES.COM",
#     "DNS2.NAME-SERVICES.COM",
#     "DNS3.NAME-SERVICES.COM",
#     "DNS4.NAME-SERVICES.COM",
#     "DNS5.NAME-SERVICES.COM"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited https://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": "ABUSE@ENOM.COM",
#   "dnssec": "unsigned",
#   "name": "REDACTED FOR PRIVACY",
#   "org": "REDACTED FOR PRIVACY",
#   "address": "REDACTED FOR PRIVACY",
#   "city": "REDACTED FOR PRIVACY",
#   "state": "CT",
#   "zipcode": "REDACTED FOR PRIVACY",
#   "country": "US"
# }
# Error trying to connect to socket: closing socket
# {
#   "domain_id": null,
#   "domain_name": null,
#   "creation_date": null,
#   "expiration_date": null,
#   "updated_date": null,
#   "dnssec": null,
#   "registrar": null,
#   "registrar_city": null,
#   "registrar_postal_code": null,
#   "registrar_country": null,
#   "registrar_phone": null,
#   "registrar_email": null,
#   "status": null,
#   "registrant_id": null,
#   "registrant_name": null,
#   "registrant_org": null,
#   "registrant_address": null,
#   "registrant_address2": null,
#   "registrant_address3": null,
#   "registrant_city": null,
#   "registrant_country": null,
#   "registrant_postal_code": null,
#   "registrant_phone": null,
#   "registrant_fax": null,
#   "registrant_email": null,
#   "name_servers": null
# }
# {
#   "domain_name": [
#     "MYLUST.COM",
#     "mylust.com"
#   ],
#   "registrar": "Eurodns S.A.",
#   "whois_server": "whois.eurodns.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-11-13 03:56:06",
#     "2021-11-13 05:20:28"
#   ],
#   "creation_date": [
#     "2004-11-19 05:50:20",
#     "2004-11-19 00:00:00"
#   ],
#   "expiration_date": [
#     "2022-11-19 05:50:20",
#     "2022-11-18 00:00:00"
#   ],
#   "name_servers": [
#     "CARTER.NS.CLOUDFLARE.COM",
#     "GWEN.NS.CLOUDFLARE.COM",
#     "carter.ns.cloudflare.com",
#     "gwen.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "legalservices@eurodns.com",
#     "accounts@yourlust.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Admin Host",
#   "org": "Web Prime, Inc.",
#   "address": "Azuero Business Center, Suite 445,, Avenida Perez Chitre,",
#   "city": "Panama",
#   "state": null,
#   "zipcode": "0601-00395",
#   "country": "PA"
# }
# {
#   "domain_name": [
#     "COX.COM",
#     "cox.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-02-03 06:16:16",
#     "2021-02-03 01:16:16"
#   ],
#   "creation_date": [
#     "1995-03-23 05:00:00",
#     "1995-03-23 00:00:00"
#   ],
#   "expiration_date": "2022-02-07 14:42:01",
#   "name_servers": [
#     "NS.COX.NET",
#     "NS.EAST.COX.NET",
#     "NS.WEST.COX.NET",
#     "ns.cox.net",
#     "ns.east.cox.net",
#     "ns.west.cox.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "InetDomainAdmin@cox.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Inet Domain Admin",
#   "org": "Cox Communications, Inc",
#   "address": "6305 Peachtree Dunwoody Rd",
#   "city": "Atlanta",
#   "state": "GA",
#   "zipcode": "30328",
#   "country": "US"
# }
# {
#   "domain_name": "MEDIUM.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-04-21 23:16:31",
#   "creation_date": "1998-05-27 04:00:00",
#   "expiration_date": "2022-05-26 04:00:00",
#   "name_servers": [
#     "ALINA.NS.CLOUDFLARE.COM",
#     "KIP.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "MIC.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-07-14 10:33:10",
#   "creation_date": "1993-09-30 04:00:00",
#   "expiration_date": "2030-09-29 04:00:00",
#   "name_servers": [
#     "NS-1532.AWSDNS-63.ORG",
#     "NS-1871.AWSDNS-41.CO.UK",
#     "NS-326.AWSDNS-40.COM",
#     "NS-566.AWSDNS-06.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "TECHCRUNCH.COM",
#     "techcrunch.com"
#   ],
#   "registrar": "MarkMonitor, Inc.",
#   "whois_server": "whois.markmonitor.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-05-10 09:08:31",
#     "2021-12-17 00:12:45"
#   ],
#   "creation_date": "2005-06-10 22:56:20",
#   "expiration_date": [
#     "2022-06-10 22:56:20",
#     "2022-06-10 07:00:00"
#   ],
#   "name_servers": [
#     "NS1.TECHCRUNCH.COM",
#     "NS2.TECHCRUNCH.COM",
#     "NS3.TECHCRUNCH.COM",
#     "NS4.TECHCRUNCH.COM",
#     "ns3.techcrunch.com",
#     "ns1.techcrunch.com",
#     "ns2.techcrunch.com",
#     "ns4.techcrunch.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited https://icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "serverUpdateProhibited (https://www.icann.org/epp#serverUpdateProhibited)",
#     "serverTransferProhibited (https://www.icann.org/epp#serverTransferProhibited)",
#     "serverDeleteProhibited (https://www.icann.org/epp#serverDeleteProhibited)"
#   ],
#   "emails": [
#     "abusecomplaints@markmonitor.com",
#     "whoisrequest@markmonitor.com"
#   ],
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Yahoo Assets LLC",
#   "address": null,
#   "city": null,
#   "state": "VA",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "WIKIMAPIA.ORG",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-01-27 08:00:23",
#     "2021-01-27 08:00:19"
#   ],
#   "creation_date": "2006-01-26 21:09:47",
#   "expiration_date": [
#     "2024-01-26 21:09:47",
#     "2022-01-26 21:09:47"
#   ],
#   "name_servers": [
#     "NS1.FIRST-NS.DE",
#     "ROBOTNS2.SECOND-NS.DE",
#     "ROBOTNS3.SECOND-NS.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": "Not Applicable",
#   "zipcode": null,
#   "country": "RU"
# }
# {
#   "domain_name": "putlocker.is",
#   "registrant_name": "DM316-IS",
#   "name": null,
#   "address": [
#     "BG",
#     "8 East concourse",
#     "Beaumaris, VIC 3193",
#     "AU"
#   ],
#   "creation_date": [
#     "2019-12-10 00:00:00",
#     "2016-01-06 00:00:00",
#     "2018-04-10 00:00:00"
#   ],
#   "expiration_date": "2022-12-10 00:00:00",
#   "email": "above.com@privacy.above.com",
#   "name_servers": [
#     "ns1.above.com",
#     "ns2.above.com"
#   ],
#   "dnssec": "unsigned delegation"
# }
# {
#   "domain_name": [
#     "HUBPAGES.COM",
#     "hubpages.com"
#   ],
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-03-24 23:10:35",
#     "2021-03-24 23:10:36.215000"
#   ],
#   "creation_date": "2005-04-28 00:32:00",
#   "expiration_date": "2022-04-28 00:32:00",
#   "name_servers": [
#     "NS-1345.AWSDNS-40.ORG",
#     "NS-1714.AWSDNS-22.CO.UK",
#     "NS-413.AWSDNS-51.COM",
#     "NS-577.AWSDNS-08.NET",
#     "ns-1345.awsdns-40.org",
#     "ns-1714.awsdns-22.co.uk",
#     "ns-413.awsdns-51.com",
#     "ns-577.awsdns-08.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "renewPeriod https://icann.org/epp#renewPeriod"
#   ],
#   "emails": [
#     "abuse@amazonaws.com",
#     "owner-10762181@hubpages.com.whoisprivacyservice.org",
#     "admin-10762181@hubpages.com.whoisprivacyservice.org",
#     "tech-10762181@hubpages.com.whoisprivacyservice.org"
#   ],
#   "dnssec": "unsigned",
#   "name": "On behalf of hubpages.com owner",
#   "org": "Whois Privacy Service",
#   "address": "P.O. Box 81226",
#   "city": "Seattle",
#   "state": "WA",
#   "zipcode": "98108-1226",
#   "country": "US"
# }
# {
#   "domain_name": "189.cn",
#   "registrar": "\u963f\u91cc\u4e91\u8ba1\u7b97\u6709\u9650\u516c\u53f8\uff08\u4e07\u7f51\uff09",
#   "creation_date": "2004-05-04 02:14:07",
#   "expiration_date": "2028-05-04 02:14:07",
#   "name_servers": [
#     "ns3.chinanet.cn",
#     "ns1.chinanet.cn",
#     "ns2.chinanet.cn"
#   ],
#   "status": [
#     "serverDeleteProhibited",
#     "serverUpdateProhibited",
#     "serverTransferProhibited"
#   ],
#   "emails": "domain@chinatelecom.cn",
#   "dnssec": "unsigned",
#   "name": "\u4e2d\u56fd\u7535\u4fe1\u96c6\u56e2\u6709\u9650\u516c\u53f8"
# }
# {
#   "domain_name": "TORCACHE.NET",
#   "registrar": "Sea Wasp, LLC",
#   "whois_server": "whois.fabulous.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-04-13 06:08:49",
#     "2021-04-13 01:08:49"
#   ],
#   "creation_date": [
#     "2011-04-29 11:29:16",
#     "2011-04-29 06:29:16"
#   ],
#   "expiration_date": [
#     "2022-04-29 11:29:16",
#     "2022-04-29 06:29:16"
#   ],
#   "name_servers": [
#     "NS1.BODIS.COM",
#     "NS2.BODIS.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "renewPeriod (https://www.icann.org/epp#renewPeriod)"
#   ],
#   "emails": [
#     "abuse@fabulous.com",
#     "torcache.net@fab.JewellaPrivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Jewella Privacy - 1aa47",
#   "org": "Jewella Privacy LLC Privacy ID# 1183090",
#   "address": "5860 Citrus Blvd, Suite D, #172",
#   "city": "Harahan",
#   "state": "LA",
#   "zipcode": "70123",
#   "country": "US"
# }
# Error trying to connect to socket: closing socket
# {
#   "domain_name": "THENEXTWEB.COM",
#   "registrar": "NameCheap, Inc.",
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": "2021-07-03 07:38:47",
#   "creation_date": "2008-08-02 19:06:27",
#   "expiration_date": "2022-08-02 19:06:27",
#   "name_servers": [
#     "ANUJ.NS.CLOUDFLARE.COM",
#     "ROSA.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@namecheap.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "KAKAKU.COM",
#     "kakaku.com"
#   ],
#   "registrar": "GMO INTERNET, INC.",
#   "whois_server": "whois.discount-domain.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-06-21 15:16:06",
#     "2021-06-22 00:16:06"
#   ],
#   "creation_date": "1998-07-08 04:00:00",
#   "expiration_date": "2022-07-07 04:00:00",
#   "name_servers": [
#     "NS-1440.AWSDNS-52.ORG",
#     "NS-1784.AWSDNS-31.CO.UK",
#     "NS-333.AWSDNS-41.COM",
#     "NS-566.AWSDNS-06.NET",
#     "ns-566.awsdns-06.net",
#     "ns-333.awsdns-41.com",
#     "ns-1440.awsdns-52.org",
#     "ns-1784.awsdns-31.co.uk"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@gmo.jp",
#     "domainadmins@kakaku.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "domain admins",
#   "org": "Kakaku.com, Inc.",
#   "address": "3-5-7 Ebisu-minami",
#   "city": "Shibuya-ku",
#   "state": "Tokyo",
#   "zipcode": "150-0022",
#   "country": "JP"
# }
# {
#   "domain_name": "censor.net.ua",
#   "status": "clientTransferProhibited",
#   "registrar": "\u0422\u041e\u0412 \u201c\u0406\u041d\u0422\u0415\u0420\u041d\u0415\u0422 \u0406\u041d\u0412\u0415\u0421\u0422\u201d",
#   "registrar_name": "co.imena",
#   "registrar_url": "http://www.imena.com.ua",
#   "registrar_country": "UA",
#   "registrar_city": "Kyiv",
#   "registrar_address": "Ukraine 01103 Kiev 50, Gaidara str.",
#   "registrar_email": "hostmaster@imena.com.ua",
#   "registrant_name": "\u0422\u041e\u0412 \u201c\u0406\u041d\u0422\u0415\u0420\u041d\u0415\u0422 \u0406\u041d\u0412\u0415\u0421\u0422\u201d",
#   "registrant_country": null,
#   "registrant_city": null,
#   "registrant_state": null,
#   "registrant_address": null,
#   "registrant_email": null,
#   "registrant_postal_code": null,
#   "registrant_phone": "+380.442010102",
#   "registrant_fax": null,
#   "admin": null,
#   "admin_country": null,
#   "admin_city": null,
#   "admin_state": null,
#   "admin_address": null,
#   "admin_email": null,
#   "admin_postal_code": null,
#   "admin_phone": null,
#   "admin_fax": null,
#   "updated_date": "2021-06-04 13:13:05",
#   "creation_date": "2004-08-31 01:00:00",
#   "expiration_date": "2022-08-31 15:00:00",
#   "name_servers": [
#     "ben.ns.cloudflare.com",
#     "abby.ns.cloudflare.com"
#   ]
# }
# {
#   "domain_name": "FISHKI.NET",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-05-15 11:46:55",
#     "2021-05-15 06:46:54"
#   ],
#   "creation_date": [
#     "2004-05-10 18:12:55",
#     "2004-05-10 13:12:55"
#   ],
#   "expiration_date": [
#     "2031-05-10 18:12:55",
#     "2031-05-10 13:12:55"
#   ],
#   "name_servers": [
#     "ADA.NS.CLOUDFLARE.COM",
#     "JAMES.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Domains By Proxy, LLC",
#   "address": null,
#   "city": null,
#   "state": "Arizona",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "ONEDIO.COM",
#   "registrar": "Name.com, Inc.",
#   "whois_server": "whois.name.com",
#   "referral_url": null,
#   "updated_date": "2021-04-15 05:27:25",
#   "creation_date": "2010-11-27 15:20:17",
#   "expiration_date": "2030-11-27 15:20:17",
#   "name_servers": [
#     "HEATHER.NS.CLOUDFLARE.COM",
#     "WOZ.NS.CLOUDFLARE.COM",
#     "woz.ns.cloudflare.com",
#     "heather.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited https://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": "abuse@name.com",
#   "dnssec": [
#     "unsigned",
#     "unSigned"
#   ],
#   "name": "Onedio Bilisim",
#   "org": "Onedio Bilisim Yazilim Medya Tekn. San. Tic. A.S",
#   "address": "ODTU Teknokent BIM , Mustafa Kemal Mah. Dumlup?nar Blv. 280-G",
#   "city": "Ankara",
#   "state": "Cankaya",
#   "zipcode": "06520",
#   "country": "TR"
# }
# {
#   "domain_name": [
#     "INDIANEXPRESS.COM",
#     "indianexpress.com"
#   ],
#   "registrar": "GoDaddy.com, LLC",
# ...
#   "referral_url": null,
#   "updated_date": "2021-04-21 23:16:31",
#   "creation_date": "1998-05-27 04:00:00",
#   "expiration_date": "2022-05-26 04:00:00",
#   "name_servers": [
#     "ALINA.NS.CLOUDFLARE.COM",
#     "KIP.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "DEADSPIN.COM",
#     "deadspin.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-10-18 05:30:41",
#     "2021-10-18 01:30:41"
#   ],
#   "creation_date": [
#     "2001-10-21 19:11:37",
#     "2001-10-21 15:11:37"
#   ],
#   "expiration_date": "2022-10-21 19:11:37",
#   "name_servers": [
#     "NS-110.AWSDNS-13.COM",
#     "NS-1146.AWSDNS-15.ORG",
#     "NS-1835.AWSDNS-37.CO.UK",
#     "NS-624.AWSDNS-14.NET",
#     "ns-1146.awsdns-15.org",
#     "ns-110.awsdns-13.com",
#     "ns-1835.awsdns-37.co.uk",
#     "ns-624.awsdns-14.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "dnsadmin@gizmodomedia.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "DNS Admin",
#   "org": "G/O Media Inc",
#   "address": "1540 Broadway 27th Floor",
#   "city": "New York",
#   "state": "NY",
#   "zipcode": "10036",
#   "country": "US"
# }
# {
#   "domain_name": "correios.com.br",
#   "registrant_name": "Empresa Brasileira de Correios e Tel\ufffdgrafos",
#   "registrant_id": "34.028.316/0001-03",
#   "country": "BR",
#   "owner_c": "GIMCO87",
#   "admin_c": null,
#   "tech_c": "GSSRE2",
#   "billing_c": null,
#   "name_server": [
#     "ns1.correios.com.br 201.48.198.145",
#     "ns2.correios.com.br 201.48.199.16"
#   ],
#   "nsstat": "20220123 AA",
#   "nslastaa": "20220123",
#   "saci": null,
#   "creation_date": [
#     "1997-10-30 00:00:00",
#     "2016-11-22 00:00:00",
#     "2016-11-23 00:00:00"
#   ],
#   "updated_date": [
#     "2021-10-04 00:00:00",
#     "2021-08-02 00:00:00",
#     "2016-11-23 00:00:00"
#   ],
#   "expiration_date": "2028-10-30 00:00:00",
#   "status": [
#     "20220123 DSOK",
#     "published"
#   ],
#   "nic_hdl_br": [
#     "GIMCO87",
#     "GSSRE2"
#   ],
#   "person": [
#     "Ger\ufffdncia de Imagem e Marcas - Correios",
#     "Ger\ufffdncia de Seguran\ufffda e Servi\ufffdos de Rede"
#   ],
#   "email": [
#     "admdominios@correios.com.br",
#     "dprorseguranca@correios.com.br"
#   ]
# }
# {
#   "domain_name": "SEEKINGALPHA.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-07-31 23:24:45",
#   "creation_date": "2004-09-03 20:40:52",
#   "expiration_date": "2022-09-03 20:40:52",
#   "name_servers": [
#     "NS-1331.AWSDNS-38.ORG",
#     "NS-1782.AWSDNS-30.CO.UK",
#     "NS-243.AWSDNS-30.COM",
#     "NS-795.AWSDNS-35.NET"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "THEMEFOREST.NET",
#     "themeforest.net"
#   ],
#   "registrar": "MarkMonitor, Inc.",
#   "whois_server": "whois.markmonitor.com",
#   "referral_url": null,
#   "updated_date": "2021-10-26 09:21:17",
#   "creation_date": "2007-11-27 03:49:29",
#   "expiration_date": [
#     "2023-11-27 03:49:29",
#     "2023-11-27 00:00:00"
#   ],
#   "name_servers": [
#     "EMMA.NS.CLOUDFLARE.COM",
#     "FRED.NS.CLOUDFLARE.COM",
#     "fred.ns.cloudflare.com",
#     "emma.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited https://icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)",
#     "serverUpdateProhibited (https://www.icann.org/epp#serverUpdateProhibited)",
#     "serverTransferProhibited (https://www.icann.org/epp#serverTransferProhibited)",
#     "serverDeleteProhibited (https://www.icann.org/epp#serverDeleteProhibited)"
#   ],
#   "emails": [
#     "abusecomplaints@markmonitor.com",
#     "whoisrequest@markmonitor.com"
#   ],
#   "dnssec": "signedDelegation",
#   "name": null,
#   "org": "Envato Pty Ltd",
#   "address": null,
#   "city": null,
#   "state": "Victoria",
#   "zipcode": null,
#   "country": "AU"
# }
# {
#   "domain_name": "MEDIUM.COM",
#   "registrar": "Amazon Registrar, Inc.",
#   "whois_server": "whois.registrar.amazon.com",
#   "referral_url": null,
#   "updated_date": "2021-04-21 23:16:31",
#   "creation_date": "1998-05-27 04:00:00",
#   "expiration_date": "2022-05-26 04:00:00",
#   "name_servers": [
#     "ALINA.NS.CLOUDFLARE.COM",
#     "KIP.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@amazonaws.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "THENEXTWEB.COM",
#     "thenextweb.com"
#   ],
#   "registrar": "NAMECHEAP INC",
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-07-03 07:38:47",
#     "2021-07-03 07:38:47.410000"
#   ],
#   "creation_date": "2008-08-02 19:06:27",
#   "expiration_date": "2022-08-02 19:06:27",
#   "name_servers": [
#     "ANUJ.NS.CLOUDFLARE.COM",
#     "ROSA.NS.CLOUDFLARE.COM",
#     "anuj.ns.cloudflare.com",
#     "rosa.ns.cloudflare.com"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": [
#     "abuse@namecheap.com",
#     "b4743c8cb7b94c60ab163a66bd49a1fb.protect@withheldforprivacy.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Redacted for Privacy",
#   "org": "Privacy service provided by Withheld for Privacy ehf",
#   "address": "Kalkofnsvegur 2",
#   "city": "Reykjavik",
#   "state": "Capital Region",
#   "zipcode": "101",
#   "country": "IS"
# }
# {
#   "domain_name": [
#     "JALOPNIK.COM",
#     "jalopnik.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-08-09 20:57:36",
#     "2021-08-09 16:57:36"
#   ],
#   "creation_date": [
#     "2004-09-08 22:37:56",
#     "2004-09-08 18:37:56"
#   ],
#   "expiration_date": "2022-09-08 22:37:56",
#   "name_servers": [
#     "NS-110.AWSDNS-13.COM",
#     "NS-1146.AWSDNS-15.ORG",
#     "NS-1835.AWSDNS-37.CO.UK",
#     "NS-624.AWSDNS-14.NET",
#     "ns-1146.awsdns-15.org",
#     "ns-110.awsdns-13.com",
#     "ns-1835.awsdns-37.co.uk",
#     "ns-624.awsdns-14.net"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "dnsadmin@gizmodomedia.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "DNS Admin",
#   "org": "G/O Media Inc",
#   "address": "1540 Broadway 27th Floor",
#   "city": "New York",
#   "state": "NY",
#   "zipcode": "10036",
#   "country": "US"
# }
# {
#   "domain_name": "otomoto.pl",
#   "name_servers": "ns1.verticals.olx.org. \r\r\n                       ns2.verticals.olx.org. \r\r\n                       ns3.verticals.olx.org. \r\r\n                       ns4.verticals.olx.org.",
#   "registrar": "Corporation Service Company",
#   "registrar_url": null,
#   "status": null,
#   "registrant_name": null,
#   "creation_date": "2004-06-14 17:25:27",
#   "expiration_date": "2022-06-14 17:25:27",
#   "updated_date": "2021-06-05 07:06:19"
# }
# {
#   "domain_name": "EXTRATORRENT.CC",
#   "registrar": "Internet Domain Service BS Corp.",
#   "whois_server": "whois.internet.bs",
#   "referral_url": null,
#   "updated_date": "2017-04-07 13:41:31",
#   "creation_date": "2010-12-03 12:08:35",
#   "expiration_date": "2023-12-03 12:08:35",
#   "name_servers": [
#     "HUGH.NS.CLOUDFLARE.COM",
#     "ZARA.NS.CLOUDFLARE.COM",
#     "hugh.ns.cloudflare.com",
#     "zara.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited - http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "abuse@internet.bs",
#     "extratorrent.cc-owner-qwlz@customers.whoisprivacycorp.com",
#     "extratorrent.cc-admin-ohqs@customers.whoisprivacycorp.com",
#     "extratorrent.cc-tech-uefr@customers.whoisprivacycorp.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "Domain Admin",
#   "org": "Whois Privacy Corp.",
#   "address": "Ocean Centre, Montagu Foreshore, East Bay Street",
#   "city": "Nassau",
#   "state": "New Providence",
#   "zipcode": null,
#   "country": "BS"
# }
# {
#   "domain_name": [
#     "GRANTLAND.COM",
#     "grantland.com"
#   ],
#   "registrar": "CSC CORPORATE DOMAINS, INC.",
#   "whois_server": "whois.corporatedomains.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-04-28 07:06:56",
#     "2021-04-28 03:06:56"
#   ],
#   "creation_date": [
#     "1997-06-12 04:00:00",
#     "1997-06-12 00:00:00"
#   ],
#   "expiration_date": "2022-06-11 04:00:00",
#   "name_servers": [
#     "NS1.WORDPRESS.COM",
#     "NS2.WORDPRESS.COM",
#     "NS3.WORDPRESS.COM",
#     "ns1.wordpress.com",
#     "ns2.wordpress.com",
#     "ns3.wordpress.com"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited"
#   ],
#   "emails": [
#     "domainabuse@cscglobal.com",
#     "domreg@espn.com"
#   ],
#   "dnssec": "unsigned",
#   "name": "ESPN, Inc.",
#   "org": "ESPN, Inc.",
#   "address": "935 Middle Street",
#   "city": "Bristol",
#   "state": "CT",
#   "zipcode": "06010-1001",
#   "country": "US"
# }
# {
#   "domain_name": "EMGN.COM",
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-06-21 18:07:52",
#     "2021-06-21 13:07:50"
#   ],
#   "creation_date": [
#     "2004-06-20 18:57:38",
#     "2004-06-20 13:57:38"
#   ],
#   "expiration_date": [
#     "2022-06-20 18:57:38",
#     "2022-06-20 13:57:38"
#   ],
#   "name_servers": [
#     "NS-1508.AWSDNS-60.ORG",
#     "NS-1606.AWSDNS-08.CO.UK",
#     "NS-185.AWSDNS-23.COM",
#     "NS-894.AWSDNS-47.NET"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "Domains By Proxy, LLC",
#   "address": null,
#   "city": null,
#   "state": "Arizona",
#   "zipcode": null,
#   "country": "US"
# }
# Error trying to connect to socket: closing socket
# {
#   "domain_name": "INTERPARK.COM",
#   "registrar": "Gabia, Inc.",
#   "whois_server": "whois.gabia.com",
#   "referral_url": null,
#   "updated_date": "2021-12-30 04:22:17",
#   "creation_date": "1996-02-11 05:00:00",
#   "expiration_date": "2023-02-12 05:00:00",
#   "name_servers": [
#     "NS.INTERPARK.COM",
#     "NS2.INTERPARK.COM"
#   ],
#   "status": "ok https://icann.org/epp#ok",
#   "emails": "abuse@gabia.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": "censor.net.ua",
#   "status": "clientTransferProhibited",
#   "registrar": "\u0422\u041e\u0412 \u201c\u0406\u041d\u0422\u0415\u0420\u041d\u0415\u0422 \u0406\u041d\u0412\u0415\u0421\u0422\u201d",
#   "registrar_name": "co.imena",
#   "registrar_url": "http://www.imena.com.ua",
#   "registrar_country": "UA",
#   "registrar_city": "Kyiv",
#   "registrar_address": "Ukraine 01103 Kiev 50, Gaidara str.",
#   "registrar_email": "hostmaster@imena.com.ua",
#   "registrant_name": "\u0422\u041e\u0412 \u201c\u0406\u041d\u0422\u0415\u0420\u041d\u0415\u0422 \u0406\u041d\u0412\u0415\u0421\u0422\u201d",
#   "registrant_country": null,
#   "registrant_city": null,
#   "registrant_state": null,
#   "registrant_address": null,
#   "registrant_email": null,
#   "registrant_postal_code": null,
#   "registrant_phone": "+380.442010102",
#   "registrant_fax": null,
#   "admin": null,
#   "admin_country": null,
#   "admin_city": null,
#   "admin_state": null,
#   "admin_address": null,
#   "admin_email": null,
#   "admin_postal_code": null,
#   "admin_phone": null,
#   "admin_fax": null,
#   "updated_date": "2021-06-04 13:13:05",
#   "creation_date": "2004-08-31 01:00:00",
#   "expiration_date": "2022-08-31 15:00:00",
#   "name_servers": [
#     "ben.ns.cloudflare.com",
#     "abby.ns.cloudflare.com"
#   ]
# }
# {
#   "domain_name": [
#     "WPENGINE.COM",
#     "wpengine.com"
#   ],
#   "registrar": "MarkMonitor, Inc.",
#   "whois_server": "whois.markmonitor.com",
#   "referral_url": null,
#   "updated_date": [
#     "2019-10-29 20:19:25",
#     "2019-11-20 21:02:02"
#   ],
#   "creation_date": "2010-03-10 21:28:12",
#   "expiration_date": "2023-03-10 21:28:12",
#   "name_servers": [
#     "JIM.NS.CLOUDFLARE.COM",
#     "KARA.NS.CLOUDFLARE.COM",
#     "kara.ns.cloudflare.com",
#     "jim.ns.cloudflare.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)",
#     "clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)",
#     "clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)"
#   ],
#   "emails": [
#     "abusecomplaints@markmonitor.com",
#     "whoisrequest@markmonitor.com"
#   ],
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "WPEngine, Inc.",
#   "address": null,
#   "city": null,
#   "state": "TX",
#   "zipcode": null,
#   "country": "US"
# }
# {
#   "domain_name": "ROCKETNEWS24.COM",
#   "registrar": "eNom, LLC",
#   "whois_server": "whois.enom.com",
#   "referral_url": null,
#   "updated_date": "2021-09-01 09:00:54",
#   "creation_date": "2008-11-29 09:50:23",
#   "expiration_date": "2030-11-29 09:50:23",
#   "name_servers": [
#     "NS1.WORDPRESS.COM",
#     "NS2.WORDPRESS.COM",
#     "NS3.WORDPRESS.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": null,
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "zipcode": null,
#   "country": null
# }
# {
#   "domain_name": [
#     "IFTTT.COM",
#     "ifttt.com"
#   ],
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2021-07-15 17:47:06",
#     "2021-07-15 12:47:04"
#   ],
#   "creation_date": [
#     "2009-07-14 17:19:46",
#     "2009-07-14 12:19:46"
#   ],
#   "expiration_date": [
#     "2022-07-14 17:19:46",
#     "2022-07-14 12:19:46"
#   ],
#   "name_servers": [
#     "NS-1400.AWSDNS-47.ORG",
#     "NS-1614.AWSDNS-09.CO.UK",
#     "NS-425.AWSDNS-53.COM",
#     "NS-676.AWSDNS-20.NET"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": "abuse@godaddy.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": "IFTTT Inc",
#   "address": null,
#   "city": null,
#   "state": "California",
#   "zipcode": null,
#   "country": "US"
# }

# %%
# 11. Web traffic 
def web_traffic(url):
  try:
    url = urllib.parse.quote(url)
    rank = BeautifulSoup(urllib.request.urlopen("http://data.alexa.com/data?cli=10&dat=s&url=" + url).read(), "xml").find(
        "REACH")['RANK']
    rank = int(rank)
  except TypeError:
        return 1
  if rank <100000:
    return 1
  else:
    return 2

# %%
legiturldata['web_traffic'] = legitdataset['URLs'].apply(web_traffic)

# %%
#12. Domain Registration Length
def domain_registration_length_sub(domain):
    expiration_date = domain.expiration_date
    today = time.strftime('%Y-%m-%d')
    today = datetime.strptime(today, '%Y-%m-%d')
    if expiration_date is None:
        return 1
    elif type(expiration_date) is list or type(today) is list :
        return 2             #If it is a type of list then we can't select a single value from list. So,it is regarded as suspected website  
    else:
        registration_length = abs((expiration_date - today).days)
        if registration_length / 365 <= 1:
            return 1
        else:
            return 0

# %%
def domain_registration_length_main(domain):
    dns = 0
    try:
        domain_name = whois.whois(domain)
    except:
        dns = 1
        
    if dns == 1:
        return 1
    else:
        return domain_registration_length_sub(domain_name)

# %%
legiturldata['domain_registration_length'] = legitdataset['URLs'].apply(domain_registration_length_main)
# Out:
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket

# %%
#13. Statistical-Reports  Based Feature
def statistical_report(url):
    hostname = url
    h = [(x.start(0), x.end(0)) for x in re.finditer('https://|http://|www.|https://www.|http://www.', hostname)]
    z = int(len(h))
    if z != 0:
        y = h[0][1]
        hostname = hostname[y:]
        h = [(x.start(0), x.end(0)) for x in re.finditer('/', hostname)]
        z = int(len(h))
        if z != 0:
            hostname = hostname[:h[0][0]]
    url_match=re.search('at\.ua|usa\.cc|baltazarpresentes\.com\.br|pe\.hu|esy\.es|hol\.es|sweddy\.com|myjino\.ru|96\.lt|ow\.ly',url)
    try:
        ip_address = socket.gethostbyname(hostname)
        ip_match=re.search('146\.112\.61\.108|213\.174\.157\.151|121\.50\.168\.88|192\.185\.217\.116|78\.46\.211\.158|181\.174\.165\.13|46\.242\.145\.103|121\.50\.168\.40|83\.125\.22\.219|46\.242\.145\.98|107\.151\.148\.44|107\.151\.148\.107|64\.70\.19\.203|199\.184\.144\.27|107\.151\.148\.108|107\.151\.148\.109|119\.28\.52\.61|54\.83\.43\.69|52\.69\.166\.231|216\.58\.192\.225|118\.184\.25\.86|67\.208\.74\.71|23\.253\.126\.58|104\.239\.157\.210|175\.126\.123\.219|141\.8\.224\.221|10\.10\.10\.10|43\.229\.108\.32|103\.232\.215\.140|69\.172\.201\.153|216\.218\.185\.162|54\.225\.104\.146|103\.243\.24\.98|199\.59\.243\.120|31\.170\.160\.61|213\.19\.128\.77|62\.113\.226\.131|208\.100\.26\.234|195\.16\.127\.102|195\.16\.127\.157|34\.196\.13\.28|103\.224\.212\.222|172\.217\.4\.225|54\.72\.9\.51|192\.64\.147\.141|198\.200\.56\.183|23\.253\.164\.103|52\.48\.191\.26|52\.214\.197\.72|87\.98\.255\.18|209\.99\.17\.27|216\.38\.62\.18|104\.130\.124\.96|47\.89\.58\.141|78\.46\.211\.158|54\.86\.225\.156|54\.82\.156\.19|37\.157\.192\.102|204\.11\.56\.48|110\.34\.231\.42',ip_address)  
    except:
        return 1

    if url_match:
        return 1
    else:
        return 0

# %%
legiturldata['statistical_report'] = legiturldata['domain_name'].apply(statistical_report)

# %% [markdown]
# ### **3.HTML and JavaScript based Features**
#
#
# *   IFrame Redirection
# *   Status Bar Customization

# %%
import requests
import re

# %%
#14.iFrame Redirection
def iframe_sub(response):
  if response == "":
      return 1
  else:
      if re.findall(r"[<iframe>|<frameBorder>]", response.text):
          return 0
      else:
          return 1

# %%
def iframe_main(url):
  try:
    response = requests.get(url)
  except:
    response = ''
  
  return iframe_sub(response)

# %%
legiturldata['iframe'] = legitdataset['URLs'].apply(iframe_main)

# %%
#15. Status Bar Customization 
def mouse_over_sub(response): 
  if response == "" :
    return 1
  else:
    if re.findall("<script>.+onmouseover.+</script>", response.text):
      return 1
    else:
      return 0

# %%
def mouse_over_main(url):
  try:
    response = requests.get(url)
  except:
    response = ''
  
  return mouse_over_sub(response)

# %%
legiturldata['mouse_over'] = legitdataset['URLs'].apply(mouse_over_main)

# %%
legiturldata['label'] = 0

# %%
legiturldata.shape

# %%
legiturldata.head()

# %% [markdown]
# ## Storing the extracted legitimate URLs fatures to csv file

# %%
legiturldata.to_csv('extracted_legitmate_dataset.csv',index=False)
